# %%
# Import dependencies
import pandas as pd
import os

# %%
# Read file into DataFrame
#team_one = os.path.join('../','Resources', 'pools.csv')
#df= pd.read_csv(team_one)
pool_df = pd.read_csv('../Resources/ratings_and_sentiments.csv')
pool_df
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 3     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# ...                               ...
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7614               The Steeping Room
# 7615               The Steeping Room
#
#                                             review_text           rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...  5.0 star rating
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...  4.0 star rating
# 2     11/30/2016 1 check-in Listed in food seating I...  4.0 star rating
# 3     11/25/2016 Very cool vibe! Good drinks Nice se...  2.0 star rating
# 4     12/3/2016 1 check-in They are location within ...  4.0 star rating
# ...

# %%
# Find all reviews with a number rating greater than or equal to 4.
#rating= (pool_df['num_rating']>=4).value_counts()
rating_df= pool_df[pool_df['num_rating']>=4]
len(rating_df)
# Out:
# 6140

# %%
# Find all the coffee shops with a overall sentiment greater than or equal to 4.
overall_df = pool_df[pool_df['overall_sent']>=4]
len(overall_df)
# Out:
# 32

# %%
len(pool_df[(pool_df['overall_sent']>=4) & (pool_df['num_rating']>=4)])
# Out:
# 32

# %%
# Return the count of the above query.
len(pool_df[(pool_df['overall_sent'] >= 4) & (pool_df['num_rating'] >= 4)])
# Out:
# 32

# %%
# Change the name of the review_text column to review
pool_df.rename (columns = {'review_text':'review'})
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 3     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# ...                               ...
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7614               The Steeping Room
# 7615               The Steeping Room
#
#                                                  review           rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...  5.0 star rating
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...  4.0 star rating
# 2     11/30/2016 1 check-in Listed in food seating I...  4.0 star rating
# 3     11/25/2016 Very cool vibe! Good drinks Nice se...  2.0 star rating
# 4     12/3/2016 1 check-in They are location within ...  4.0 star rating
# ...

# %%
# Change the name of the bool_HIGH column to bool_high
pool_df.rename(columns = {'bool_HIGH':'bool_high'})
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 3     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# ...                               ...
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7614               The Steeping Room
# 7615               The Steeping Room
#
#                                             review_text           rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...  5.0 star rating
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...  4.0 star rating
# 2     11/30/2016 1 check-in Listed in food seating I...  4.0 star rating
# 3     11/25/2016 Very cool vibe! Good drinks Nice se...  2.0 star rating
# 4     12/3/2016 1 check-in They are location within ...  4.0 star rating
# ...

# %%
# Save your changes to the file as a pipe delimited file.
pool_df.to_csv('pool_df',sep= '|')

# %%
pool_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7616 entries, 0 to 7615
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coffee_shop_name  7616 non-null   object
#  1   review_text       7616 non-null   object
#  2   rating            7616 non-null   object
#  3   num_rating        7616 non-null   int64
#  4   cat_rating        7616 non-null   object
#  5   bool_HIGH         7616 non-null   int64
#  6   overall_sent      7616 non-null   int64
#  7   vibe_sent         4507 non-null   object
#  8   tea_sent          7616 non-null   int64
#  9   service_sent      7616 non-null   int64
#  10  seating_sent      7616 non-null   int64
#  11  price_sent        7616 non-null   int64
#  12  parking_sent      7616 non-null   object
#  13  location_sent     7616 non-null   int64
#  14  alcohol_sent      7616 non-null   int64
#  15  coffee_sent       7616 non-null   object
# ...

# %%
len(pool_df)
# Out:
# 7616
